# %% [markdown]
# Description

# %%
#install libraries
import pandas as pd
import json

# %%
#upload raw query data

#upload manually tagged articles

# %%
#Class Balance
#For the query, how many relavant/irrelavant articles are included in each cosine bin?

#Statistics
#Text Statistics: 
#Compare word counts and sentence lengths between relevant and irrelevant articles.

#Keyword Analysis: 
#covariance matrix of keywords

# %%
import pandas as pd

# 1. Filter for relevant articles
manual_tagged_keywords = df[df['label'] == 'relevant']
total_relevant_count = len(relevant_df)

# 3. Count occurrences of each keyword


# 4. Calculate smoothed probability
alpha = 1
probabilities = (keyword_counts + alpha) / (total_relevant_count + alpha * 2)

print(probabilities.sort_values(ascending=False).head(10))
