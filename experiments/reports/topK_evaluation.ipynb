# %%
#Set up

#install libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from tueplots import bundles
from tueplots.constants.color import rgb
from matplotlib.lines import Line2D
from tueplots.constants.color.palettes import paultol_vibrant 


# set plotting stylesheet
plt.rcParams.update(bundles.icml2024(column='half', nrows=1, ncols=1)) #test different rows and columns

import sys
print(sys.executable)

#set source and output paths
source_path = '../../data/'
csv_output_path = '../../data/processed/'
figure_output_path = '../../paper/figures/'

#upload raw query data
df_32_raw = pd.read_csv(f'{source_path}repository_queries/500000_32_homicide-female_DE.csv') 
#upload manually tagged articles with json data
df_tag = pd.read_csv(f'{source_path}processed/manual-tag_all_parsedson.csv')
#filter to only ones with T/F data
df_tag_valid = df_tag.dropna(subset=['woman_murdered'])
#upload keyword data
df_key = pd.read_csv(f'{source_path}manual_tag/femicide_keywords.csv')
#upload top k data
df_50 = pd.read_csv(f'{source_path}processed/7-9_22_24_26-27_31-32_2017-2023_top50.csv')
df_25 = pd.read_csv(f'{source_path}processed/7-14_22-24_26-27_29-32_2017-2023_top25.csv')
#final dataset
final = pd.read_csv(f'{source_path}final_dataset_t225.csv')
# Out:
# /Users/madelinemiller/Desktop/data_literacy/geonews_femicide/source/.venv/bin/python

# %%
#filters for raw data
#data filtered to only one entry per NUTS and date between 2017 -2023
df_32_raw['NUTS'] = df_32_raw['NUTS'].fillna('').astype(str)
print(f'df 32 raw  shape: {df_32_raw.shape}')
df_32 = df_32_raw.groupby('id').agg({
    'NUTS': lambda x: ', '.join(sorted(set(code for code in x if code.startswith('DE')))),
    'url': 'first',
    'hostname': 'first',
    'date': 'first',
    'cos_dist': 'first', # these values will all be the same
    'hashed_id': 'first',
    'date_crawled': 'first'
    }).reset_index()
#remove null NUTS
df_32 = df_32[df_32['NUTS'].notna()]
df_32 = df_32[df_32['NUTS']!='']

print(f'df 32 nuts condensed shape: {df_32.shape}')
#Convert the date column to datetime objects
df_32['date'] = pd.to_datetime(df_32['date'])      
# Filter for dates
df_32 = df_32[(df_32['date'].dt.year >= 2017) & (df_32['date'].dt.year <= 2023)]
print(f'df 32 date removed shape: {df_32.shape}')
df_32_nothresh = df_32
df_32 = df_32[df_32['cos_dist']<=.225].copy()
print(f'shape of df_32 with threshold: {df_32.shape}')
# Out:
# df 32 raw  shape: (1143913, 13)
# df 32 nuts condensed shape: (375215, 8)
# df 32 date removed shape: (364570, 8)
# shape of df_32 with threshold: (31368, 8)

# %%
#select only id
df_sampled = df_tag.dropna(subset=['query_32_cosine_bin', 'woman_murdered']).copy()
#get list of ids
sampled_ids = df_sampled['id']
print(len(sampled_ids))
#filter raw dataset to just those ids
df_32_sampled = df_32_nothresh[df_32_nothresh['id'].isin(sampled_ids)].copy()
print(df_32_sampled.shape)
# Out:
# 677
# (677, 8)

# %%
def removedup_cosdist_source(df):
    #how many total items in dataset have same hostname and cosine distance
    #add column to check article duplicates if the article has the same source and same cosine distance
    df['cos_hostname_duplicate_count'] = df.groupby(['cos_dist', 'hostname'])['cos_dist'].transform('count')

    total_duplicates= df[df['cos_hostname_duplicate_count']>1].shape
    
    # mark retained rows
    df['retained'] = ~df.duplicated(
        subset=['cos_dist', 'hostname'],
        keep='first'
    )
    
    #filter to only rows with duplicates and save csv
    
    df[df['cos_hostname_duplicate_count']>1].to_csv(f'{csv_output_path}duplicate_q32thresh_flagged.csv', index=False)
    
    # keep only retained rows
    df_dupsremoved = df[df['retained']].copy()
    
    print(f'df_dupsremoved: {df_dupsremoved.shape}')
    totaldupsremoved = df.shape[0] - df_dupsremoved.shape[0]
    uniquedups = total_duplicates[0] - totaldupsremoved
    print(f'total duplicates: {total_duplicates[0]}')
    print(f'total_duplicates_removed = {totaldupsremoved}')
    print(f'remaining unique = {uniquedups}')

    return df_dupsremoved

# %%
df_32_nodups = removedup_cosdist_source(df_32)
nodup_ids_32 = df_32_nodups['id']

df_tag_nodups = df_tag[df_tag['id'].isin(nodup_ids_32)]
print(df_tag.shape)
print(df_tag_nodups.shape)
# Out:
# df_dupsremoved: (30195, 10)
# total duplicates: 2087
# total_duplicates_removed = 1173
# remaining unique = 914
# (1191, 19)
# (604, 19)

# %%
def query_relevant_list(df_topk, topk, df_tag, k=None, removedup=False): 
    # join tagging information to top k
    #left join means only articles that were part of topk check are retained
    df_query = df_topk.merge(df_tag[['id', 'woman_murdered','URL_works']], on='id', how='left')
    print(f"\nshape topk: {df_topk.shape}")
    print(f"shape topk tagged: {df_query.shape}")
    # Convert all pd.NA to np.nan in the entire dataframe
    df_query = df_query.fillna(np.nan)

    if k is None:
        k = topk
    
    # Get list of queries
    queries = [col.removeprefix('cos_rank_') for col in df_query.columns if col.startswith('cos_rank_')]
    
    query_list = []  # List to store all query results
    summary_list = []  # List to store summary per query
    
    # For each query: create records with article id, relevance, cosine distance, and rank
    for query in queries:
        rank_col = f'cos_rank_{query}'
        dist_col = f'cos_dist_{query}'

        # Filter to only rows that have previous topk data
        #(we don't want to rank if it wasn't in original topk
        df_query_subset = df_query[df_query[rank_col]<=topk].copy()

        # Create updated ranking (only ranks rows where woman_murdered is not null)
        df_query_subset['new_rank_dense'] = np.nan  # Initialize with NaN
        mask = df_query_subset['woman_murdered'].notna()  # Identify rows to rank
        df_query_subset.loc[mask, 'new_rank'] = (
            df_query_subset.loc[mask, dist_col]
                .rank(method='dense', na_option='keep')
                .astype(float)
        )

        df_query_subset['new_rank_min'] = np.nan  # Initialize with NaN
        mask = df_query_subset['woman_murdered'].notna()  # Identify rows to rank
        df_query_subset.loc[mask, 'new_rank_min'] = (
            df_query_subset.loc[mask, dist_col]
                .rank(method='min', na_option='keep')
                .astype(float)
        )
        #remove duplicate cosine distances
        if removedup != False: 
            df_query_subset = df_query_subset.drop_duplicates(
            subset=[dist_col],
            keep='first'
        )
  
        # Normalized cosine distance
        df_query_subset['mstd_norm_cos_dist'] = (df_query_subset[dist_col] - df_query_subset[dist_col].mean()) / df_query_subset[dist_col].std()
        min_val = df_query_subset[dist_col].min()
        max_val = df_query_subset[dist_col].max()
        range_val = max_val - min_val
        df_query_subset['minshift_norm_cos_dist'] = df_query_subset[dist_col] - min_val
        df_query_subset['minmax_norm_cos_dist'] = (df_query_subset[dist_col] - min_val) / range_val

        # Create records for THIS query only (create temporary list)
        current_query_records = []
    
        for _, row in df_query_subset.iterrows():
            record = {
                'query': query,
                'id': row['id'],
                'relevance': row['woman_murdered'],
                'cosine_distance': row[dist_col],
                'original_rank': row[rank_col],
                'new_rank': row['new_rank'],
                'new_rank_min': row['new_rank_min'],
                'url_works': row['URL_works'], 
                'mstd_norm_cos_dist': row['mstd_norm_cos_dist'],
                'minshift_norm_cos_dist': row['minshift_norm_cos_dist'], 
                'minmax_norm_cos_dist': row['minmax_norm_cos_dist'] 
            }

            query_list.append(record)
            current_query_records.append(record) 
        
      # Create summary for query using current_query_records
        relevant = sum(1 for r in current_query_records if r['relevance'] == True)
        irrelevant = sum(1 for r in current_query_records if r['relevance'] == False)
        not_checkable = sum(1 for r in current_query_records if pd.isna(r['relevance']))
        
        # Calculate additional summary stats
        original_ranks = [r['original_rank'] for r in current_query_records if not pd.isna(r['original_rank'])]
        new_ranks = [r['new_rank'] for r in current_query_records if not pd.isna(r['new_rank'])]
        
        relevant_norankdups = sum(1 for r in current_query_records 
                                  if r['relevance'] == True 
                                  and isinstance(r.get('new_rank_min'), (int, float))  # only numeric
                                  and r['new_rank_min'] <= k)
        irrelevant_norankdups = sum(1 for r in current_query_records 
                                    if r['relevance'] == False 
                                    and isinstance(r.get('new_rank_min'), (int, float))  # only numeric
                                    and r['new_rank_min'] <= k)
       
        summary_list.append({
            'query': query,
            'total_articles': len(current_query_records),
            'relevant_count': relevant,
            'irrelevant_count': irrelevant,
            'relevant_norankdups': relevant_norankdups,
            'irrelevant_norankdups': irrelevant_norankdups,
            'not_checked_count': not_checkable,
            'total_valid': relevant+irrelevant
        })
    
    # Convert to DataFrames
    df_individual = pd.DataFrame(query_list)
    df_summary = pd.DataFrame(summary_list)
    
    # Print summary
    print(f"Total records created: {len(query_list)}")
    print(f"Number of queries: {len(queries)}")
    
    return queries, df_individual, df_summary

# %%
df_50_querylist, df_50_individual, df_50_summary  = query_relevant_list(df_50, topk=50, df_tag=df_tag_valid)
df_25_querylist, df_25_individual, df_25_summary = query_relevant_list(df_25, topk=25, df_tag=df_tag_valid)
#without dups
df_50_querylist_nodups, df_50_individual_nodups, df_50_summary_nodups  = query_relevant_list(
    df_50, topk=50, df_tag=df_tag_valid, removedup = True)
df_25_querylist_nodups, df_25_individual_nodups, df_25_summary_nodups = query_relevant_list(
    df_25, topk=25, df_tag=df_tag_valid, removedup = True)
# Out:
# shape topk: (306, 24)
# shape topk tagged: (306, 26)
# Total records created: 450
# Number of queries: 9
#
# shape topk: (263, 40)
# shape topk tagged: (263, 42)
# Total records created: 425
# Number of queries: 17
#
# shape topk: (306, 24)
# shape topk tagged: (306, 26)
# Total records created: 404
# Number of queries: 9
#
# shape topk: (263, 40)
# shape topk tagged: (263, 42)
# Total records created: 382
# Number of queries: 17

# %%
df_25_summary[
    df_25_summary['irrelevant_count'] == 0
].sort_values(by='relevant_count', ascending=False)
# Out:
#                                   query  total_articles  relevant_count  \
# 0   7_police-report-gender-motivated_EN              25              24
# 16                32_homicide-female_DE              25              24
# 13             29_woman-was-murdered_DE              25              23
# 14               30_woman-was-killed_DE              25              23
# 2                9_woman-girl-killed_EN              25              22
#
#     irrelevant_count  relevant_norankdups  irrelevant_norankdups  \
# 0                  0                   24                      0
# 16                 0                   24                      0
# 13                 0                   23                      0
# 14                 0                   23                      0
# 2                  0                   22                      0
#
#     not_checked_count  total_valid
# 0                   1           24
# 16                  1           24
# 13                  2           23
# 14                  2           23
# 2                   3           22

# %%
df_25_summary_nodups[
    df_25_summary['irrelevant_count'] == 0
].sort_values(by='relevant_count', ascending=False)

#the cosine duplicate in query 7 is from different publishers
# Out:
#                                   query  total_articles  relevant_count  \
# 16                32_homicide-female_DE              24              23
# 0   7_police-report-gender-motivated_EN              23              22
# 13             29_woman-was-murdered_DE              24              22
# 2                9_woman-girl-killed_EN              22              19
# 14               30_woman-was-killed_DE              20              18
#
#     irrelevant_count  relevant_norankdups  irrelevant_norankdups  \
# 16                 0                   23                      0
# 0                  0                   22                      0
# 13                 0                   22                      0
# 2                  0                   19                      0
# 14                 0                   18                      0
#
#     not_checked_count  total_valid
# 16                  1           23
# 0                   1           22
# 13                  2           22
# 2                   3           19
# 14                  2           18

# %%
df_50_summary_table = (
    df_50_summary
    .sort_values(by='relevant_count', ascending=False)
    [['query', 'relevant_count', 'irrelevant_count', 'not_checked_count']]  # <- double brackets
    .reset_index(drop=True)
    .iloc[:2]   # remove after first two rows
)

df_25_summary_table = (
    df_25_summary
    .sort_values(by='relevant_count', ascending=False)
    [['query', 'relevant_count', 'irrelevant_count', 'not_checked_count']]  # <- double brackets
    .reset_index(drop=True)
    .iloc[2:]   # remove first two rows
)


df_50_summary_table

#latex_table = df_50_summary_table.to_latex(index=False, longtable=False)
#print(latex_table)
# Out:
#                                  query  relevant_count  irrelevant_count  \
# 0                32_homicide-female_DE              45                 0
# 1  7_police-report-gender-motivated_EN              43                 0
#
#    not_checked_count
# 0                  5
# 1                  7

# %%
df_50_individual.head(18)
# Out:
#                                   query                                    id  \
# 0   7_police-report-gender-motivated_EN  600f9f30-15cc-435d-9cab-56d475bd02f8
# 1   7_police-report-gender-motivated_EN  282205b9-ce04-4462-b96d-d37ac43b6eca
# 2   7_police-report-gender-motivated_EN  d6d2633e-35b4-4496-8896-e57b9bea0ac8
# 3   7_police-report-gender-motivated_EN  2d9f1ebf-e4f4-4f74-96d6-208bd48239f4
# 4   7_police-report-gender-motivated_EN  4c54bc18-901a-4dae-8448-d6ea02c1a8f1
# 5   7_police-report-gender-motivated_EN  3fcd7328-b5e2-4332-acff-e0bf19c10b7b
# 6   7_police-report-gender-motivated_EN  6930fda1-eb47-4764-9055-20e91ae3e06f
# 7   7_police-report-gender-motivated_EN  f2e45b88-90be-40ed-afd4-bc29b4a23780
# 8   7_police-report-gender-motivated_EN  14f7d286-a405-457b-8d2c-4e9af1453f1d
# 9   7_police-report-gender-motivated_EN  7135e616-8ac2-47f0-87cd-adbe2b4866ab
# 10  7_police-report-gender-motivated_EN  937d426f-9cef-41c7-a553-46dbdc84ee85
# 11  7_police-report-gender-motivated_EN  2bb5ee01-ba1d-4a2a-bba4-dbded361e4aa
# 12  7_police-report-gender-motivated_EN  e2398709-f15b-480c-a80c-740d7b60d52c
# 13  7_police-report-gender-motivated_EN  ca81322d-6710-473b-a290-61a2776d5aa0
# 14  7_police-report-gender-motivated_EN  2ecdeaa9-8f42-4224-8a64-07d0c802154c
# 15  7_police-report-gender-motivated_EN  89cf93f9-6ed6-44f3-af04-ecc8b70c8c08
# 16  7_police-report-gender-motivated_EN  480fd1ed-af75-48d0-a05d-1721fff3240b
# 17  7_police-report-gender-motivated_EN  e26081ed-bed5-4b05-92d6-025b4a262a2b
#
#    relevance  cosine_distance  original_rank  new_rank  new_rank_min  \
# 0       True         0.233323            1.0       1.0           1.0
# 1       True         0.236274            2.0       2.0           2.0
# 2       True         0.238673            3.0       3.0           3.0
# 3       True         0.241098            4.0       4.0           4.0
# 4       True         0.241323            5.0       5.0           5.0
# 5       True         0.242415            6.0       6.0           6.0
# 6       True         0.244852            7.0       7.0           7.0
# 7       True         0.245268            8.0       8.0           8.0
# 8       True         0.245324            9.0       9.0           9.0
# 9       True         0.245769           10.0      10.0          10.0
# 10      True         0.246003           11.0      11.0          11.0
# 11      True         0.246322           12.0      12.0          12.0
# 12      True         0.246822           13.0      13.0          13.0
# 13      True         0.247981           14.0      14.0          14.0
# 14      True         0.248803           15.0      15.0          15.0
# 15      True         0.248881           16.0      16.0          16.0
# 16      True         0.249374           17.0      17.0          17.0
# 17      True         0.249374           17.0      17.0          17.0
#
#                        url_works  mstd_norm_cos_dist  minshift_norm_cos_dist  \
# 0                         Active           -3.201285                0.000000
# 1                         Active           -2.629400                0.002951
# 2   404 or redirect to home page           -2.164577                0.005350
# 3   404 or redirect to home page           -1.694802                0.007775
# 4                         Active           -1.651056                0.008001
# 5                         Active           -1.439509                0.009092
# 6                         Active           -0.967303                0.011529
# 7   404 or redirect to home page           -0.886734                0.011945
# 8                         Active           -0.875782                0.012002
# 9                         Active           -0.789667                0.012446
# 10  404 or redirect to home page           -0.744233                0.012681
# 11                        Active           -0.682558                0.012999
# 12  404 or redirect to home page           -0.585612                0.013499
# 13                        Active           -0.361068                0.014658
# 14                        Active           -0.201714                0.015480
# 15                        Active           -0.186720                0.015558
# 16                        Active           -0.091220                0.016051
# 17                        Active           -0.091220                0.016051
#
#     minmax_norm_cos_dist
# 0               0.000000
# 1               0.134855
# 2               0.244464
# 3               0.355241
# 4               0.365557
# 5               0.415441
# 6               0.526791
# 7               0.545790
# 8               0.548372
# 9               0.568679
# 10              0.579393
# 11              0.593936
# 12              0.616797
# 13              0.669746
# 14              0.707323
# 15              0.710859
# 16              0.733379
# 17              0.733379

# %%
finalDataIds = final['id']

# %%
def plot_cos_outcomes(df_individual, x_col='cos_dist_', rel_col ='cos_dist_' , query_order=None, query_order_labels=None,
                        mainquery=None, threshold=None, tagdata=None, lengthstart=0, lengthend=1, jitter_amount=0.15, finalDataIds=finalDataIds):
    
    # Get width from Tueplots, calculate height based on queries
    fig, ax = plt.subplots()  # Let tueplots control sizing

    colors = ['#' + c for c in paultol_vibrant]
    """
    width = plt.rcParams['figure.figsize'][0]
    height = len(query_order) * 0.4  # Adjust multiplier as needed
    fig, ax = plt.subplots(figsize=(width, height))    
    """
    added_irr_legend = False 
    
    for i, query in enumerate(query_order):
        y_pos = i
        x_col = f'{x_col}{query}'

        # Filter data for this query
        query_subset = df_individual[df_individual['query'] == query]

        # Get relevant and irrelevant from the list/dataframe
        """
        #relevant and irrelevant excluded from final dataset
        relevantEF = query_subset[
            (query_subset['relevance'] == True) &
            (~query_subset['id'].isin(finalDataIds))
            ][rel_col].values
        irrelevantEF = query_subset[
            (query_subset['relevance'] == False) & 
            (~query_subset['id'].isin(finalDataIds))
            ][rel_col].values
        """

        #relevant and irrelevant not excluded from final dataset
        relevant = query_subset[
            (query_subset['relevance'] == True) &
            (query_subset['id'].isin(finalDataIds))
            ][rel_col].values
    
        irrelevant = query_subset[
            (query_subset['relevance'] == False) & 
            (query_subset['id'].isin(finalDataIds))
            ][rel_col].values
        

        #relevance could not be determined
        na = query_subset.loc[query_subset['relevance'].isna(), rel_col].values

        # number of articles 
        #n_rEF = relevantEF.shape[0] 
        #n_iEF = irrelevantEF.shape[0] 
        n_r = relevant.shape[0]
        n_i = irrelevant.shape[0]
        n_na = na.shape[0] 

        #random int (for jitter)
        #u_rEF = np.random.rand(n_rEF)  
        #u_iEF = np.random.rand(n_iEF) 
        u_r = np.random.rand(n_r)  
        u_i = np.random.rand(n_i)  
        u_na = np.random.rand(n_na)  

        ms_size =  plt.rcParams['lines.markersize'] * 0.7  # Scale relative to default

        #plot
        """
        ax.plot(relevantEF, -.4 * u_rEF+y_pos,
                's', alpha=0.6, color=rgb.tue_blue, ms=ms_size, 
                mec='black', markeredgewidth=plt.rcParams['lines.linewidth'] * 0.5,
                label='')
        ax.plot(irrelevantEF, .4*u_iEF+y_pos,
                's', alpha=0.6, color=rgb.tue_orange, ms=ms_size, 
                mec='black', markeredgewidth=plt.rcParams['lines.linewidth'] * 0.5,
                label='')
        """
        jitter_scale =.8

        if n_i > 0:
            # Relevant -> upper half
            ax.plot(relevant, (-u_r * jitter_scale/2) + y_pos,  # 0 to +jitter_scale/2
                'o', alpha=0.6, 
                    color=colors[0], 
                    ms=ms_size, mec='none', 
                label='Relevant' if i == 0 else '')

            # Irrelevant -> lower half
            ax.plot(irrelevant, (u_i * jitter_scale/2) + y_pos,  # 0 to -jitter_scale/2
                'o', alpha=0.6, 
                    color=colors[3], 
                    ms=ms_size, mec='none', 
                label='Irrelevant' if not added_irr_legend else '')
            added_irr_legend = True
        else:
            # Only relevant exists -> take full row
            ax.plot(relevant, (u_r - 0.5)*jitter_scale + y_pos,  # values from -0.5 to +0.5
                'o', alpha=0.6, 
                    color=colors[0], 
                    ms=ms_size, mec='none', 
                label='Relevant' if i == 0 else '')
         
        #NAN stay around center
        ax.plot(na, (-.001 * u_na)+y_pos,
                'o', alpha=0.6, 
                color=colors[6], 
                ms=ms_size, mec='none', 
                label='Undetermined' if i == 0 else '')
        
    ax.set_yticks(range(len(query_order)))
    #ax.set_yticklabels(query_order_labels)
    ax.set_yticklabels(query_order_labels, fontsize=10)

    
    #split between queries
    for i in range(len(query_order)):
        if i > 0:
            ax.axhline(i - 0.5, color='black', alpha=1, linewidth=plt.rcParams['lines.linewidth']*.5)
    """
    #add legend for excluded
    excluded_handle = Line2D(
        [], [], marker='s', linestyle='None',
        markerfacecolor='white',
        markeredgecolor='black',
        markersize=ms_size,
        markeredgewidth=plt.rcParams['lines.linewidth'] * 0.5,
        label='Excl'
    )
    """
            
    ax.set_xlabel('Cosine Distance',fontsize=10)
    ax.tick_params(axis='x', labelsize=10)
    #ax.set_xlim(lengthstart, lengthend)
    #ax.set_ylim(-0.5, len(query_order) - 0.5)
    ax.grid(axis='x', alpha=0.3)
    ax.legend(
        #handles=ax.get_legend_handles_labels()[0] + [excluded_handle],
        loc='upper right',
        fontsize=8,
        facecolor = 'white',framealpha=1) #white non-transparent background, 
    ax.set_title(f"Article Cosine Distance by Query with Relevance",fontsize=10)
    ax.invert_yaxis()#reverse so that query order is correct

    return fig, ax

# %%
plt.rcParams.update(bundles.icml2024(column='half', nrows=1.7, ncols=1))
query_order_50 = [
    '32_homicide-female_DE',
    '7_police-report-gender-motivated_EN',
    '8_police-report-gender-motivated_DE',
    '26_femicide_Femicide_EN',
    '22_femicide_Femizid_DE'
    ]

query_order_50_labels = [
    'A. (selected)\nTötungsdelikt*',
    'B1.\nPolicereport*',
    'B2.\nPolizeibericht*',
    'C1.\nFemicide',
    'C2.\nFemizid'
    ]

fig,ax = plot_cos_outcomes(df_50_individual, x_col='cos_dist_', rel_col ='cosine_distance' , query_order = query_order_50, 
                        query_order_labels = query_order_50_labels,
                        mainquery=None, threshold=None, tagdata=None, lengthstart=.16, lengthend=.26)
plt.tight_layout()
fig.savefig(f"{figure_output_path}fig_cosdist_querycomp_50_gnf.pdf", bbox_inches="tight")
# Out:
# /var/folders/8y/qtlvpscd259873sjdt05kvlm0000gn/T/ipykernel_14864/3397169457.py:21: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
from tueplots import bundles

def plot_cos_outcomes(
    df_individual,
    x_col_prefix="cos_dist_",
    rel_col="cosine_distance",
    query_order=None,
    query_order_labels=None,
    lengthstart=0.0,
    lengthend=1.0,
    finalDataIds=None,
    paultol_vibrant=None,
    jitter_scale=0.8,          
    row_height=0.38,           
    base_height=0.55,          
    label_fontsize=10,
    tickpad=2,
):
    """
    Less-tight version:
    - Compact but not squished: height = row_height * nrows + base_height
    - Legend bottom-right inside axes
    - 'UNKNOWN' label
    """

    if query_order is None:
        raise ValueError("query_order must be provided")
    if query_order_labels is None:
        query_order_labels = query_order
    if finalDataIds is None:
        finalDataIds = []
    finalDataIds = set(finalDataIds)

    # Colors
    if paultol_vibrant is None:
        colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#7f7f7f"]
    else:
        colors = ["#" + c for c in paultol_vibrant]

    # Figure sizing: keep tueplots width, choose a better height
    width = plt.rcParams["figure.figsize"][0]
    n = len(query_order)
    height = row_height * n + base_height
    fig, ax = plt.subplots(figsize=(width, height))

    added_irr_legend = False

    for i, query in enumerate(query_order):
        y_pos = i
        query_subset = df_individual[df_individual["query"] == query]

        relevant = query_subset[
            (query_subset["relevance"] == True) &
            (query_subset["id"].isin(finalDataIds))
        ][rel_col].values

        irrelevant = query_subset[
            (query_subset["relevance"] == False) &
            (query_subset["id"].isin(finalDataIds))
        ][rel_col].values

        unknown = query_subset.loc[query_subset["relevance"].isna(), rel_col].values

        n_r, n_i, n_u = relevant.size, irrelevant.size, unknown.size
        u_r = np.random.rand(n_r) if n_r else np.array([])
        u_i = np.random.rand(n_i) if n_i else np.array([])
        u_u = np.random.rand(n_u) if n_u else np.array([])

        ms_size = plt.rcParams["lines.markersize"] * 0.7

        if n_i > 0:
            # Relevant (upper half)
            ax.plot(
                relevant,
                (-u_r * jitter_scale / 2) + y_pos,
                "o",
                alpha=0.6,
                color=colors[0],
                ms=ms_size,
                mec="none",
                label="Relevant" if i == 0 else "",
            )

            # Irrelevant (lower half)
            ax.plot(
                irrelevant,
                (u_i * jitter_scale / 2) + y_pos,
                "o",
                alpha=0.6,
                color=colors[3],
                ms=ms_size,
                mec="none",
                label="Irrelevant" if not added_irr_legend else "",
            )
            added_irr_legend = True
        else:
            ax.plot(
                relevant,
                (u_r - 0.5) * jitter_scale + y_pos,
                "o",
                alpha=0.6,
                color=colors[0],
                ms=ms_size,
                mec="none",
                label="Relevant" if i == 0 else "",
            )

        ax.plot(
            unknown,
            (u_u - 0.5) * 0.06 + y_pos,
            "o",
            alpha=0.6,
            color=colors[6],
            ms=ms_size,
            mec="none",
            label="Unknown" if i == 0 else "",
        )

    # y axis formatting
    ax.set_yticks(range(len(query_order)))
    ax.set_yticklabels(query_order_labels, fontsize=label_fontsize)
    ax.tick_params(axis="y", pad=tickpad)

    # separators
    for i in range(1, len(query_order)):
        ax.axhline(i - 0.5, color="black", alpha=1, linewidth=plt.rcParams["lines.linewidth"] * 0.5)

    ax.set_xlabel("Cosine Distance", fontsize=label_fontsize)
    ax.tick_params(axis="x", labelsize=label_fontsize)
    ax.set_xlim(lengthstart, lengthend)
    ax.grid(axis="x", alpha=0.3)

    ax.set_title("Article Cosine Distance by Query with Relevance", fontsize=label_fontsize)
    ax.invert_yaxis()

    handles, labels = ax.get_legend_handles_labels()

    order = ["Relevant", "Irrelevant", "Unknown"]
    label_to_handle = dict(zip(labels, handles))

    ordered_handles = [label_to_handle[l] for l in order if l in label_to_handle]
    ordered_labels  = [l for l in order if l in label_to_handle]

    ax.legend(
        ordered_handles,
        ordered_labels,
        loc="lower right",
        framealpha=1,
        facecolor="white",
        borderpad=0.25,
        handletextpad=0.25,
        handlelength=0.9,
        labelspacing=0.25,
        fontsize=9,
        bbox_to_anchor=(1.01, 0.02),
    )

    fig.tight_layout(pad=0.2)
    return fig, ax

# -------------------------
plt.rcParams.update(bundles.icml2024(column="half", nrows=1.7, ncols=1))

query_order_50 = [
    "32_homicide-female_DE",
    "7_police-report-gender-motivated_EN",
    "8_police-report-gender-motivated_DE",
    "26_femicide_Femicide_EN",
    "22_femicide_Femizid_DE",
]

query_order_50_labels = [
    "A. (selected)\nTötungsdelikt*",
    "B1.\nPolicereport*",
    "B2.\nPolizeibericht*",
    "C1.\nFemicide",
    "C2.\nFemizid",
]

fig, ax = plot_cos_outcomes(
    df_50_individual,
    x_col_prefix="cos_dist_",
    rel_col="cosine_distance",
    query_order=query_order_50,
    query_order_labels=query_order_50_labels,
    lengthstart=0.16,
    lengthend=0.26,
    finalDataIds=finalDataIds,
    paultol_vibrant=paultol_vibrant,
    row_height=0.38,     
    base_height=0.55,
    label_fontsize=10,
)

fig.savefig(f"{figure_output_path}fig_cosdist_querycomp_50_gnf.pdf", bbox_inches="tight", pad_inches=0.03)
plt.show()

# %%
plt.rcParams.update(bundles.icml2024(column='half', nrows=1, ncols=1))

query_order_25 = [
    "32_homicide-female_DE",
    "7_police-report-gender-motivated_EN",
    "8_police-report-gender-motivated_DE",
    #"27_femicide_femicide_EN",
    #"26_femicide_Femicide_EN",
    #"24_femicide_Feminizid_DE",
    #"22_femicide_Femizid_DE",
    #"23_femicide_Frauenmord_DE",
    #"31_murder-woman-girl_DE",
    "11_murder-woman-victim_EN",
    "12_murder-woman-victim_DE",
    "13_victim-woman-long_EN",
    "14_victim-woman-long_DE",
    "9_woman-girl-killed_EN",
    "10_woman-girl-killed_DE"
    #"30_woman-was-killed_DE",
    #"29_woman-was-murdered_DE"
    ]

query_order_25_labels = [
    "32_homicide-female_DE",
    "7_police-report-gender-motivated_EN",
    "8_police-report-gender-motivated_DE",
    #"27_femicide_femicide_EN",
    #"26_femicide_Femicide_EN",
    #"24_femicide_Feminizid_DE",
    #"22_femicide_Femizid_DE",
    #"23_femicide_Frauenmord_DE",
    #"31_murder-woman-girl_DE",
    "11_murder-woman-victim_EN",
    "12_murder-woman-victim_DE",
    "13_victim-woman-long_EN",
    "14_victim-woman-long_DE",
    "9_woman-girl-killed_EN",
    "10_woman-girl-killed_DE"
    #"30_woman-was-killed_DE",
    #"29_woman-was-murdered_DE"
    ]

fig,ax = plot_cos_outcomes(df_25_individual, x_col='cos_dist_', rel_col ='cosine_distance' , query_order = query_order_25, 
                        query_order_labels = query_order_25_labels,
                        mainquery=None, threshold=None, tagdata=None, lengthstart=.16, lengthend=.25)
plt.tight_layout()
fig.savefig(f"{figure_output_path}fig_cosdist_querycomp_25_gnf.pdf", bbox_inches="tight")
# Out:
# /var/folders/8y/qtlvpscd259873sjdt05kvlm0000gn/T/ipykernel_14864/2826453542.py:46: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
